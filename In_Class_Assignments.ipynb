# %% [markdown]
# <a href="https://colab.research.google.com/github/ams1276/Anastasia-Smolentseva-Repository/blob/main/In_Class_Assignments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sales = float(input("Enter sales($): "))
rate = float(input("Enter tax rate (%): "))

cogs = sales * 0.4
gross_profit = sales - cogs
taxes = rate * gross_profit
net = gross_profit - taxes

print(f"Sales: {sales}$")
print(f"Cost of Goods SOLD: {cogs}$")
print(f"Gross profit: {gross_profit}$")
print(f"Taxes: {taxes}$")
print(f"Net profit: {net}$")
