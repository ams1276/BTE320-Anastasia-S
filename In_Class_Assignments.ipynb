# %% [markdown]
# <a href="https://colab.research.google.com/github/ams1276/BTE320-Anastasia-S/blob/main/In_Class_Assignments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sales = float(input("Enter sales($): "))
rate = float(input("Enter tax rate (%): "))

cogs = sales * 0.4
gross_profit = sales - cogs
taxes = rate * gross_profit
net = gross_profit - taxes

print(f"Sales: {sales}$")
print(f"Cost of Goods SOLD: {cogs}$")
print(f"Gross profit: {gross_profit}$")
print(f"Taxes: {taxes}$")
print(f"Net profit: {net}$")

# %%
num1 = float(input("Enter the first number: "))
num2 - float(input("Enter the second number: "))
op = input("Enter the operator: ")

if op == "+":
  result = num1 + num2
elif op == "-":
  result = num1 - num2
elif op == "*":
  result = num1 * num2
elif op == "/":
  result = num1 / num2
elif op == "//":
  result = num1 // num2
elif op == "**":
  result = num1 ** num2
elif op == "%":
  result = num1 % num2
else:
  print("Invalid operation")

print(f"Result: {result}")
